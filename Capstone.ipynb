# %% [markdown]
# This notebook is for the purpose of the capstone project

# %%
import pandas as pd
import NumPy as np
print("Hello capstone project course")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2ceabb95a2d2> in <module>
#       1 import pandas as pd
# ----> 2 import NumPy as np
#       3 print("Hello capstone project course")
#
# ModuleNotFoundError: No module named 'NumPy'

# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np
print("Hello capstone project course")
# Out:
# Hello capstone project course
